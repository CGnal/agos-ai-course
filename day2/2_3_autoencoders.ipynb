# %% [markdown]
# <a href="https://colab.research.google.com/github/CGnal/agos-ai-course/blob/master/2_3_autoencoders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install tensorflow

# %%
# !pip install tensorflow==2.6.2
# Out:
# Collecting tensorflow==2.6.2
#   Downloading tensorflow-2.6.2-cp37-cp37m-manylinux2010_x86_64.whl (458.3 MB)
#      |████████████████████████████████| 458.3 MB 12 kB/s
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (0.2.0)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (0.37.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (1.1.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (1.19.5)
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (3.1.0)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (3.17.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (1.1.2)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (1.6.3)
# Collecting tensorboard<2.7,>=2.6.0
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 32.2 MB/s
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (0.4.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (1.15.0)
# Collecting keras<2.7,>=2.6.0
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 39.0 MB/s
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 65.2 MB/s
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (0.12.0)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.2) (1.41.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow==2.6.2) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (57.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (4.8.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2) (3.6.0)
# Building wheels for collected packages: clang, wrapt
#   Building wheel for clang (setup.py) ... done
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30692 sha256=89d750019514cf0d15282675bab44de78ad541eab5c941591d8ebc72c79bf515
#   Stored in directory: /root/.cache/pip/wheels/98/91/04/971b4c587cf47ae952b108949b46926f426c02832d120a082a
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68712 sha256=023f2c8ae0b86034ca4852714c3503ae9fb0560cf60b6adebe255b3f6ee6df10
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built clang wrapt
# Installing collected packages: typing-extensions, wrapt, tensorflow-estimator, tensorboard, keras, flatbuffers, clang, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.13.3
#     Uninstalling wrapt-1.13.3:
#       Successfully uninstalled wrapt-1.13.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.7.0
#     Uninstalling tensorboard-2.7.0:
#       Successfully uninstalled tensorboard-2.7.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.7.0
#     Uninstalling keras-2.7.0:
#       Successfully uninstalled keras-2.7.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
# Successfully installed clang-5.0 flatbuffers-1.12 keras-2.6.0 tensorboard-2.6.0 tensorflow-2.6.2 tensorflow-estimator-2.6.0 typing-extensions-3.7.4.3 wrapt-1.12.1

# %%
# !pip install git+https://github.com/tensorflow/docs
# Out:
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-3y_6fo7i
#   Running command git clone -q https://github.com/tensorflow/docs /tmp/pip-req-build-3y_6fo7i
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (0.8.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (0.12.0)
# Requirement already satisfied: protobuf>=3.14 in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (3.17.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from tensorflow-docs==0.0.0.dev0) (3.13)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.14->tensorflow-docs==0.0.0.dev0) (1.15.0)
# Building wheels for collected packages: tensorflow-docs
#   Building wheel for tensorflow-docs (setup.py) ... done
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-0.0.0.dev0-py3-none-any.whl size=156838 sha256=7e8ea306eb843035a268d4ceca5e9a494b3108e9f7aa187a04d44f8a01079240
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8v2ivui7/wheels/cc/c4/d8/5341e93b6376c5c929c49469fce21155eb69cef1a4da4ce32c
# Successfully built tensorflow-docs
# Installing collected packages: tensorflow-docs
# Successfully installed tensorflow-docs-0.0.0.dev0

# %% [markdown]
# # Autoencoders
#
# Autoencoders are neural networks trained to reproduce the input: the model is a regressor where the target is the same as the input.
#
# Autoencoders can be used to find lower-dimensional representation of the data. In this case, one of the hidden layers, typically the middle one, is the "code", i.e. the compressed representation of the input data.

# %% [markdown]
# ![picture](https://drive.google.com/uc?id=1drlrT_f2_sAX1u65npWWv2wOLti8NfVs)

# %% [markdown]
# Contary to PCA, autoencoders are powerful non-linear models that can discover non-linear correlations among features.

# %% [markdown]
# ![picture](https://drive.google.com/uc?id=1og8kGSLkSnKIeUKg1xSAfmv5JFfIZNIt)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np

# %%
tf.__version__
# Out:
# '2.6.2'

# %%
# %load_ext tensorboard
import tensorboard
tensorboard.__version__
# Out:
# '2.6.0'

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %% [markdown]
# # Sample problem : Mnist
#
# Train a neural network model to encode images 28x28 pixels (768 pixels) representing **hand-written digits** in a 16-dimensional vector.
#
# Here, 60,000 images are used to train the network and 10,000 images to evaluate how much accurate is the lower representation. You can access the MNIST directly from TensorFlow. Import and load the MNIST data directly from TensorFlow:

# %%
mnist = tf.keras.datasets.mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# Loading the dataset returns four NumPy arrays:
#
# * The `train_images` and `train_labels` arrays are the *training set*—the data the model uses to learn.
# * The model is tested against the *test set*, the `test_images`, and `test_labels` arrays.
#
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255. The *labels* are an array of integers, ranging from 0 to 9.

# %% [markdown]
# ## Explore the data
# Image shape: 60,000 x 28 x 28
#
# Each image is represented as a 2 dimensional matrix of 28 x 28

# %%
train_images.shape,len(train_labels)
# Out:
# ((60000, 28, 28), 60000)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape, len(test_labels)
# Out:
# ((10000, 28, 28), 10000)

# %%
plt.imshow(train_images[0], cmap=plt.cm.binary)
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# ## Preprocess images
# Normalize pixel values in the range [0, 1], i.e. divide by 255.

# %%
# important to perform each processing step separately on train and test 

train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
plt.imshow(train_images[0], cmap=plt.cm.binary)
plt.xlabel(train_labels[0])
plt.show()
plt.imshow(train_images[1], cmap=plt.cm.binary)
plt.xlabel(train_labels[1])
plt.show()

# %% [markdown]
# # Build the model and pipeline using Sequential API
#
# ## Setup layers

# %%
input_img = keras.Input(shape=(28, 28), name='image')
encoded = layers.Flatten(name='flatten')(input_img)
encoded = layers.Dense(128, activation='relu', name='enc_hidden')(encoded)
encoded = layers.Dense(16, activation='relu', name='enc_output')(encoded)

decoded = layers.Dense(128, activation='relu', name='dec_hidden')(encoded)
decoded = layers.Dense(784, activation='sigmoid', name='dec_output')(decoded)
decoded = layers.Reshape((28, 28), name='reshape')(decoded)

# %% [markdown]
# ## Compile the model
#
# Compiling the model means setting up the optimizer and loss function
#
# * **Loss function** —This measures how accurate the model is during training. You want to minimize this function to "steer" the model in the right direction.
# * **Optimizer** —This is how the model is updated based on the data it sees and its loss function.

# %%
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
print(autoencoder.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# image (InputLayer)           [(None, 28, 28)]          0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# enc_hidden (Dense)           (None, 128)               100480
# _________________________________________________________________
# enc_output (Dense)           (None, 16)                2064
# _________________________________________________________________
# dec_hidden (Dense)           (None, 128)               2176
# _________________________________________________________________
# dec_output (Dense)           (None, 784)               101136
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28)            0
# =================================================================
# Total params: 205,856
# Trainable params: 205,856
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
keras.utils.plot_model(autoencoder, show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Train the model
# Training the neural network model requires the following steps:
#
# 1. Feed the training data to the model. **In an autoencoder, the input is the same as the target** (`train_images`).
# 2. The model learns to encode the image information in a 16-dimensional vector and decode it back.
# 3. You ask the model to encode and decode the original images.
# 4. Verify that the original images resembles the recovered images.

# %%
# tensorboard settings to view plots
logdir = "logs/scalars/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)


autoencoder.fit(train_images, train_images,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(test_images, test_images))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2407 - val_loss: 0.1663
# Epoch 2/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1534 - val_loss: 0.1408
# Epoch 3/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1368 - val_loss: 0.1302
# Epoch 4/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1281 - val_loss: 0.1239
# Epoch 5/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1238 - val_loss: 0.1212
# Epoch 6/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1210 - val_loss: 0.1184
# Epoch 7/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1189 - val_loss: 0.1162
# Epoch 8/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1163 - val_loss: 0.1137
# Epoch 9/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1143 - val_loss: 0.1122
# Epoch 10/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1130 - val_loss: 0.1110
# Epoch 11/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1119 - val_loss: 0.1101
# Epoch 12/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1110 - val_loss: 0.1093
# Epoch 13/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1103 - val_loss: 0.1087
# Epoch 14/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1096 - val_loss: 0.1084
# Epoch 15/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1090 - val_loss: 0.1076
# Epoch 16/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1083 - val_loss: 0.1069
# Epoch 17/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1078 - val_loss: 0.1064
# Epoch 18/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1073 - val_loss: 0.1060
# Epoch 19/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1068 - val_loss: 0.1055
# Epoch 20/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1063 - val_loss: 0.1051
# Epoch 21/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1059 - val_loss: 0.1047
# Epoch 22/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1055 - val_loss: 0.1044
# Epoch 23/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.1052 - val_loss: 0.1042
# Epoch 24/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1048 - val_loss: 0.1038
# Epoch 25/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1045 - val_loss: 0.1034
# Epoch 26/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1042 - val_loss: 0.1031
# Epoch 27/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1039 - val_loss: 0.1029
# Epoch 28/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.1036 - val_loss: 0.1026
# Epoch 29/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.1034 - val_loss: 0.1024
# Epoch 30/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1031 - val_loss: 0.1021
# Epoch 31/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1029 - val_loss: 0.1019
# Epoch 32/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.1027 - val_loss: 0.1019
# Epoch 33/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.1024 - val_loss: 0.1017
# Epoch 34/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1022 - val_loss: 0.1014
# Epoch 35/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1020 - val_loss: 0.1012
# Epoch 36/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1018 - val_loss: 0.1011
# Epoch 37/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1017 - val_loss: 0.1011
# Epoch 38/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1015 - val_loss: 0.1006
# Epoch 39/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1013 - val_loss: 0.1006
# Epoch 40/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1011 - val_loss: 0.1005
# Epoch 41/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1009 - val_loss: 0.1003
# Epoch 42/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1008 - val_loss: 0.1001
# Epoch 43/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1006 - val_loss: 0.1001
# Epoch 44/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1005 - val_loss: 0.1000
# Epoch 45/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1003 - val_loss: 0.0998
# Epoch 46/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1002 - val_loss: 0.0997
# Epoch 47/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1001 - val_loss: 0.0995
# Epoch 48/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0999 - val_loss: 0.0996
# Epoch 49/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0998 - val_loss: 0.0994
# Epoch 50/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0996 - val_loss: 0.0991
# Epoch 51/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0995 - val_loss: 0.0992
# Epoch 52/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0994 - val_loss: 0.0990
# Epoch 53/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0993 - val_loss: 0.0990
# Epoch 54/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0991 - val_loss: 0.0987
# Epoch 55/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0990 - val_loss: 0.0986
# Epoch 56/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0989 - val_loss: 0.0986
# Epoch 57/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0989 - val_loss: 0.0985
# Epoch 58/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0987 - val_loss: 0.0983
# Epoch 59/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0986 - val_loss: 0.0982
# Epoch 60/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0985 - val_loss: 0.0982
# Epoch 61/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0985 - val_loss: 0.0982
# Epoch 62/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0984 - val_loss: 0.0984
# Epoch 63/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0983 - val_loss: 0.0980
# Epoch 64/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0982 - val_loss: 0.0979
# Epoch 65/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0981 - val_loss: 0.0980
# Epoch 66/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0980 - val_loss: 0.0979
# Epoch 67/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0980 - val_loss: 0.0977
# Epoch 68/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0979 - val_loss: 0.0976
# Epoch 69/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0978 - val_loss: 0.0976
# Epoch 70/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0978 - val_loss: 0.0976
# Epoch 71/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0977 - val_loss: 0.0975
# Epoch 72/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0976 - val_loss: 0.0976
# Epoch 73/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0976 - val_loss: 0.0974
# Epoch 74/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0975 - val_loss: 0.0975
# Epoch 75/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0975 - val_loss: 0.0973
# Epoch 76/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.0974 - val_loss: 0.0972
# Epoch 77/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0973 - val_loss: 0.0971
# Epoch 78/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0973 - val_loss: 0.0972
# Epoch 79/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0972 - val_loss: 0.0971
# Epoch 80/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0972 - val_loss: 0.0970
# Epoch 81/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0971 - val_loss: 0.0970
# Epoch 82/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0971 - val_loss: 0.0968
# Epoch 83/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0970 - val_loss: 0.0969
# Epoch 84/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0970 - val_loss: 0.0968
# Epoch 85/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0969 - val_loss: 0.0969
# Epoch 86/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0969 - val_loss: 0.0968
# Epoch 87/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0968 - val_loss: 0.0968
# Epoch 88/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0968 - val_loss: 0.0966
# Epoch 89/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0967 - val_loss: 0.0967
# Epoch 90/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0967 - val_loss: 0.0966
# Epoch 91/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0966 - val_loss: 0.0967
# Epoch 92/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0966 - val_loss: 0.0966
# Epoch 93/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0966 - val_loss: 0.0965
# Epoch 94/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0965 - val_loss: 0.0966
# Epoch 95/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0965 - val_loss: 0.0964
# Epoch 96/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0964 - val_loss: 0.0964
# Epoch 97/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0964 - val_loss: 0.0964
# Epoch 98/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0964 - val_loss: 0.0964
# Epoch 99/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0963 - val_loss: 0.0963
# Epoch 100/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0963 - val_loss: 0.0962

# %% [markdown]
# ## Evaluate the model on test set

# %%
decoded_imgs = autoencoder.predict(test_images)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(test_images[i])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ## Embeddings
# We use the trained layers in order to get the core representation in the middle layer of the autoencoder, and we represent them with the TSNE

# %%
embeddings = keras.Model(input_img, encoded).predict(test_images)

# %%
from sklearn.manifold import TSNE
import numpy as np

# %%
tsne = TSNE(n_components=2)

# %%
emb2d = tsne.fit_transform(embeddings)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
x,y = np.squeeze(emb2d[:, 0]), np.squeeze(emb2d[:, 1])

# %%
import pandas as pd

# %%
from matplotlib.cm import tab10

# %%
summary =  pd.DataFrame({"x": x, "y": y, "target": test_labels, "size": 10})

plt.figure(figsize=(10,8))

for key, sel in summary.groupby("target"):
    plt.scatter(sel["x"], sel["y"], s=10, color=tab10.colors[key], label=key)
    
plt.legend()
plt.axis("off")
# Out:
# (-91.9634002685547, 93.634375, -91.7695327758789, 94.77345428466796)

# %% [markdown]
# # Add denoising
# Autoencoders can be quite unstable when presented with even slightly different input distributions. In this example, we add Gaussian noise to the original images. They do seem very similar to the original images, yet the autoencoder fails to reproduce them.
#
# Denoising Autoencoders (DAE) are more robust compared to "vanilla" autoencoders.

# %%
noise_factor = 0.1
x_train_noisy = train_images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=train_images.shape) 
x_test_noisy = test_images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=test_images.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

n = 6
plt.figure(figsize=(20, 10))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(3, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    if i==1:
        plt.ylabel("Original")
    else:
        ax.get_yaxis().set_visible(False)
        
    # Display reconstruction
    ax = plt.subplot(3, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    if i==1:
        plt.ylabel("Vanilla Autoencoder")
    else:
        ax.get_yaxis().set_visible(False)
    
        
plt.show()

# %%
from tensorflow.keras.layers import GaussianNoise

# %%
input_img = keras.Input(shape=(28, 28), name='image')

noisy_input = GaussianNoise(0.1, name='gaussian_noise')(input_img)

encoded = layers.Flatten(name='flatten')(noisy_input)
encoded = layers.Dense(128, activation='relu', name='enc_hidden')(encoded)
encoded = layers.Dense(16, activation='relu', name='enc_output')(encoded)

decoded = layers.Dense(128, activation='relu', name='dec_hidden')(encoded)
decoded = layers.Dense(784, activation='sigmoid', name='dec_output')(decoded)
decoded = layers.Reshape((28, 28), name='reshape')(decoded)

# %%
noisy_autoencoder = keras.Model(input_img, decoded)
noisy_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
keras.utils.plot_model(noisy_autoencoder, show_shapes=True, show_layer_names=True)

# %%
noisy_autoencoder.fit(train_images, train_images,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(test_images, test_images))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2419 - val_loss: 0.1670
# Epoch 2/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1548 - val_loss: 0.1430
# Epoch 3/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1407 - val_loss: 0.1335
# Epoch 4/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1324 - val_loss: 0.1271
# Epoch 5/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1282 - val_loss: 0.1243
# Epoch 6/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1256 - val_loss: 0.1218
# Epoch 7/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1237 - val_loss: 0.1203
# Epoch 8/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1221 - val_loss: 0.1186
# Epoch 9/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1204 - val_loss: 0.1162
# Epoch 10/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1179 - val_loss: 0.1143
# Epoch 11/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1164 - val_loss: 0.1131
# Epoch 12/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1153 - val_loss: 0.1122
# Epoch 13/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1144 - val_loss: 0.1114
# Epoch 14/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1136 - val_loss: 0.1106
# Epoch 15/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1129 - val_loss: 0.1099
# Epoch 16/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1121 - val_loss: 0.1092
# Epoch 17/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1116 - val_loss: 0.1086
# Epoch 18/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1109 - val_loss: 0.1081
# Epoch 19/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1104 - val_loss: 0.1077
# Epoch 20/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1100 - val_loss: 0.1073
# Epoch 21/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1095 - val_loss: 0.1069
# Epoch 22/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1092 - val_loss: 0.1065
# Epoch 23/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1088 - val_loss: 0.1062
# Epoch 24/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1084 - val_loss: 0.1060
# Epoch 25/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1082 - val_loss: 0.1057
# Epoch 26/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1079 - val_loss: 0.1054
# Epoch 27/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1076 - val_loss: 0.1051
# Epoch 28/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1074 - val_loss: 0.1049
# Epoch 29/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1071 - val_loss: 0.1048
# Epoch 30/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1069 - val_loss: 0.1047
# Epoch 31/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1067 - val_loss: 0.1045
# Epoch 32/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1065 - val_loss: 0.1040
# Epoch 33/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1063 - val_loss: 0.1039
# Epoch 34/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1061 - val_loss: 0.1037
# Epoch 35/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1059 - val_loss: 0.1037
# Epoch 36/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1058 - val_loss: 0.1035
# Epoch 37/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1056 - val_loss: 0.1034
# Epoch 38/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1054 - val_loss: 0.1034
# Epoch 39/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1053 - val_loss: 0.1030
# Epoch 40/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1051 - val_loss: 0.1029
# Epoch 41/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1050 - val_loss: 0.1028
# Epoch 42/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1048 - val_loss: 0.1029
# Epoch 43/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1048 - val_loss: 0.1026
# Epoch 44/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1046 - val_loss: 0.1025
# Epoch 45/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1045 - val_loss: 0.1025
# Epoch 46/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1044 - val_loss: 0.1022
# Epoch 47/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1043 - val_loss: 0.1022
# Epoch 48/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1042 - val_loss: 0.1019
# Epoch 49/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1040 - val_loss: 0.1018
# Epoch 50/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1040 - val_loss: 0.1019
# Epoch 51/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1038 - val_loss: 0.1017
# Epoch 52/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1037 - val_loss: 0.1017
# Epoch 53/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1037 - val_loss: 0.1015
# Epoch 54/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1035 - val_loss: 0.1015
# Epoch 55/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1034 - val_loss: 0.1015
# Epoch 56/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1034 - val_loss: 0.1013
# Epoch 57/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1033 - val_loss: 0.1013
# Epoch 58/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1033 - val_loss: 0.1011
# Epoch 59/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1031 - val_loss: 0.1010
# Epoch 60/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1031 - val_loss: 0.1010
# Epoch 61/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1030 - val_loss: 0.1010
# Epoch 62/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1029 - val_loss: 0.1008
# Epoch 63/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1029 - val_loss: 0.1009
# Epoch 64/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1028 - val_loss: 0.1007
# Epoch 65/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1027 - val_loss: 0.1007
# Epoch 66/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1026 - val_loss: 0.1005
# Epoch 67/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1026 - val_loss: 0.1004
# Epoch 68/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1025 - val_loss: 0.1005
# Epoch 69/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1024 - val_loss: 0.1004
# Epoch 70/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1024 - val_loss: 0.1005
# Epoch 71/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1023 - val_loss: 0.1003
# Epoch 72/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1022 - val_loss: 0.1003
# Epoch 73/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1022 - val_loss: 0.1002
# Epoch 74/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1021 - val_loss: 0.1001
# Epoch 75/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1020 - val_loss: 0.1001
# Epoch 76/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1020 - val_loss: 0.1000
# Epoch 77/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1019 - val_loss: 0.1000
# Epoch 78/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1019 - val_loss: 0.0998
# Epoch 79/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1018 - val_loss: 0.1000
# Epoch 80/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1017 - val_loss: 0.0998
# Epoch 81/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1017 - val_loss: 0.0997
# Epoch 82/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1016 - val_loss: 0.0996
# Epoch 83/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1016 - val_loss: 0.0996
# Epoch 84/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1015 - val_loss: 0.0994
# Epoch 85/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1014 - val_loss: 0.0995
# Epoch 86/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1014 - val_loss: 0.0994
# Epoch 87/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1014 - val_loss: 0.0993
# Epoch 88/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1013 - val_loss: 0.0995
# Epoch 89/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1012 - val_loss: 0.0992
# Epoch 90/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.1012 - val_loss: 0.0992
# Epoch 91/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.1011 - val_loss: 0.0992
# Epoch 92/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1011 - val_loss: 0.0991
# Epoch 93/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1011 - val_loss: 0.0992
# Epoch 94/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1010 - val_loss: 0.0991
# Epoch 95/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1009 - val_loss: 0.0991
# Epoch 96/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1009 - val_loss: 0.0991
# Epoch 97/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1009 - val_loss: 0.0991
# Epoch 98/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1008 - val_loss: 0.0989
# Epoch 99/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1008 - val_loss: 0.0989
# Epoch 100/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1007 - val_loss: 0.0988

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

decoded_imgs_denoised = noisy_autoencoder.predict(x_test_noisy)

n = 6
plt.figure(figsize=(20, 10))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(3, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    if i==1:
        plt.ylabel("Original")
    else:
        ax.get_yaxis().set_visible(False)
        
    # Display reconstruction
    ax = plt.subplot(3, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    if i==1:
        plt.ylabel("Vanilla Autoencoder")
    else:
        ax.get_yaxis().set_visible(False)
     
    ax = plt.subplot(3, n, i + 2*n)
    plt.imshow(decoded_imgs_denoised[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    if i==1:
        plt.ylabel("Denoising Autoencoder")
    else:
        ax.get_yaxis().set_visible(False)
    
        
plt.show()

# %% [markdown]
# # Noise removal
#
# Autoencoders can have different architectures depending on the goal.
#
# In this example, the focus is on the noise removal. In this case, we do not need the encoder-decoder structure, since our goal is not to compress the images in a lower-dimensional representation bu rather to **generate new images with the noise removed**. This model belongs to the class of **generative** models.

# %%
from numpy.random import default_rng
from keras.utils import tf_utils

rng = default_rng()

def salt_and_pepper(inputs, rate):
  shp = tf.shape(inputs)
  mask_select = rng.binomial(n=1, p=rate, size=shp)
  mask_noise = rng.binomial(n=1, p=0.5, size=shp) # salt and pepper have the same chance
  out = inputs * (1-mask_select) + mask_noise * mask_select
  return out

class SaltAndPepperNoise(keras.layers.Layer):

  def __init__(self, rate, **kwargs):
    super(SaltAndPepperNoise, self).__init__(**kwargs)
    self.rate = rate

  def call(self, inputs, training=None):
    def noised():
      shp = keras.backend.shape(inputs)[1:]
      mask_select = keras.backend.random_bernoulli(shape=shp, p=self.rate)
      mask_noise = keras.backend.random_bernoulli(shape=shp, p=0.5) # salt and pepper have the same chance
      out = inputs * (1-mask_select) + mask_noise * mask_select
      return out

    return keras.backend.in_train_phase(noised(), inputs, training=training)

  @tf_utils.shape_type_conversion
  def compute_output_shape(self, input_shape):
    return input_shape

# %%
noise_rate = 0.3
train_images_saltpepper = salt_and_pepper(train_images, noise_rate)
test_images_saltpepper = salt_and_pepper(test_images, noise_rate)

# %%
input_img = keras.Input(shape=(28, 28), name='noisy_image')

noisy_input = SaltAndPepperNoise(noise_rate, name='salt_and_pepper')(input_img)

encoded = layers.Flatten(name='flatten')(noisy_input)
encoded = layers.Dense(1000, activation='relu', name='dense_hidden')(encoded)
encoded = layers.Dense(784, activation='sigmoid', name='output_image')(encoded)
output = layers.Reshape((28, 28), name='reshape')(encoded)

# %%
noise_removal_dae = keras.Model(input_img, output)
noise_removal_dae.compile(optimizer='adam', loss='binary_crossentropy')

# %%
print(noise_removal_dae.summary())
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# noisy_image (InputLayer)     [(None, 28, 28)]          0
# _________________________________________________________________
# salt_and_pepper (SaltAndPepp (None, 28, 28)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense_hidden (Dense)         (None, 1000)              785000
# _________________________________________________________________
# output_image (Dense)         (None, 784)               784784
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28)            0
# =================================================================
# Total params: 1,569,784
# Trainable params: 1,569,784
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
keras.utils.plot_model(noise_removal_dae, show_shapes=True, show_layer_names=True)

# %%
noise_removal_dae.fit(train_images, train_images,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(test_images, test_images))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 12s 48ms/step - loss: 0.1958 - val_loss: 0.1742
# Epoch 2/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1466 - val_loss: 0.1558
# Epoch 3/100
# 235/235 [==============================] - 11s 47ms/step - loss: 0.1358 - val_loss: 0.1411
# Epoch 4/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1290 - val_loss: 0.1367
# Epoch 5/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1254 - val_loss: 0.1272
# Epoch 6/100
# 235/235 [==============================] - 11s 47ms/step - loss: 0.1222 - val_loss: 0.1310
# Epoch 7/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1193 - val_loss: 0.1338
# Epoch 8/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1179 - val_loss: 0.1379
# Epoch 9/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1159 - val_loss: 0.1381
# Epoch 10/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1152 - val_loss: 0.1322
# Epoch 11/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1144 - val_loss: 0.1336
# Epoch 12/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1137 - val_loss: 0.1390
# Epoch 13/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1123 - val_loss: 0.1336
# Epoch 14/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1119 - val_loss: 0.1244
# Epoch 15/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1110 - val_loss: 0.1309
# Epoch 16/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1111 - val_loss: 0.1278
# Epoch 17/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1110 - val_loss: 0.1315
# Epoch 18/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1101 - val_loss: 0.1128
# Epoch 19/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1094 - val_loss: 0.1233
# Epoch 20/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1074 - val_loss: 0.1410
# Epoch 21/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1089 - val_loss: 0.1312
# Epoch 22/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1081 - val_loss: 0.1307
# Epoch 23/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1081 - val_loss: 0.1385
# Epoch 24/100
# 235/235 [==============================] - 11s 47ms/step - loss: 0.1073 - val_loss: 0.1227
# Epoch 25/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1073 - val_loss: 0.1159
# Epoch 26/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1069 - val_loss: 0.1203
# Epoch 27/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1062 - val_loss: 0.1187
# Epoch 28/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1065 - val_loss: 0.1116
# Epoch 29/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1066 - val_loss: 0.1196
# Epoch 30/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1063 - val_loss: 0.1227
# Epoch 31/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1058 - val_loss: 0.1112
# Epoch 32/100
# 235/235 [==============================] - 11s 47ms/step - loss: 0.1056 - val_loss: 0.1163
# Epoch 33/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1066 - val_loss: 0.1191
# Epoch 34/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1055 - val_loss: 0.1176
# Epoch 35/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1053 - val_loss: 0.1125
# Epoch 36/100
# 235/235 [==============================] - 12s 49ms/step - loss: 0.1055 - val_loss: 0.1166
# Epoch 37/100
# 235/235 [==============================] - 12s 50ms/step - loss: 0.1048 - val_loss: 0.1240
# Epoch 38/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1047 - val_loss: 0.1153
# Epoch 39/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1049 - val_loss: 0.1129
# Epoch 40/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1046 - val_loss: 0.1159
# Epoch 41/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1047 - val_loss: 0.1131
# Epoch 42/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1047 - val_loss: 0.1134
# Epoch 43/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1038 - val_loss: 0.1031
# Epoch 44/100
# 235/235 [==============================] - 12s 49ms/step - loss: 0.1044 - val_loss: 0.1060
# Epoch 45/100
# 235/235 [==============================] - 12s 49ms/step - loss: 0.1043 - val_loss: 0.1045
# Epoch 46/100
# 235/235 [==============================] - 12s 49ms/step - loss: 0.1040 - val_loss: 0.1034
# Epoch 47/100
# 235/235 [==============================] - 12s 49ms/step - loss: 0.1039 - val_loss: 0.1142
# Epoch 48/100
# 235/235 [==============================] - 12s 49ms/step - loss: 0.1037 - val_loss: 0.1088
# Epoch 49/100
# 235/235 [==============================] - 13s 55ms/step - loss: 0.1034 - val_loss: 0.1045
# Epoch 50/100
# 235/235 [==============================] - 12s 51ms/step - loss: 0.1030 - val_loss: 0.1101
# Epoch 51/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1039 - val_loss: 0.1053
# Epoch 52/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1034 - val_loss: 0.1043
# Epoch 53/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1032 - val_loss: 0.1064
# Epoch 54/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1029 - val_loss: 0.1025
# Epoch 55/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1032 - val_loss: 0.1041
# Epoch 56/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1031 - val_loss: 0.1067
# Epoch 57/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1026 - val_loss: 0.0987
# Epoch 58/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1018 - val_loss: 0.1053
# Epoch 59/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1025 - val_loss: 0.1080
# Epoch 60/100
# 235/235 [==============================] - 12s 49ms/step - loss: 0.1031 - val_loss: 0.1029
# Epoch 61/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1022 - val_loss: 0.1003
# Epoch 62/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1021 - val_loss: 0.1043
# Epoch 63/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1023 - val_loss: 0.1063
# Epoch 64/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1030 - val_loss: 0.1061
# Epoch 65/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1025 - val_loss: 0.1093
# Epoch 66/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1018 - val_loss: 0.1076
# Epoch 67/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1025 - val_loss: 0.1025
# Epoch 68/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1023 - val_loss: 0.1045
# Epoch 69/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1016 - val_loss: 0.1024
# Epoch 70/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1018 - val_loss: 0.1125
# Epoch 71/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1018 - val_loss: 0.1051
# Epoch 72/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1019 - val_loss: 0.1003
# Epoch 73/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1025 - val_loss: 0.1084
# Epoch 74/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1014 - val_loss: 0.1007
# Epoch 75/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1010 - val_loss: 0.1010
# Epoch 76/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1010 - val_loss: 0.1056
# Epoch 77/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1008 - val_loss: 0.1030
# Epoch 78/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1016 - val_loss: 0.1006
# Epoch 79/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1015 - val_loss: 0.1029
# Epoch 80/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1012 - val_loss: 0.1042
# Epoch 81/100
# 235/235 [==============================] - 12s 49ms/step - loss: 0.1012 - val_loss: 0.1030
# Epoch 82/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1011 - val_loss: 0.1058
# Epoch 83/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1010 - val_loss: 0.1025
# Epoch 84/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1010 - val_loss: 0.0984
# Epoch 85/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1005 - val_loss: 0.1037
# Epoch 86/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1006 - val_loss: 0.0989
# Epoch 87/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1011 - val_loss: 0.1016
# Epoch 88/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1005 - val_loss: 0.1012
# Epoch 89/100
# 235/235 [==============================] - 12s 49ms/step - loss: 0.1011 - val_loss: 0.0983
# Epoch 90/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1007 - val_loss: 0.1015
# Epoch 91/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1010 - val_loss: 0.0999
# Epoch 92/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1006 - val_loss: 0.0982
# Epoch 93/100
# 235/235 [==============================] - 11s 48ms/step - loss: 0.1007 - val_loss: 0.0935
# Epoch 94/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1006 - val_loss: 0.1003
# Epoch 95/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1001 - val_loss: 0.0933
# Epoch 96/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1003 - val_loss: 0.1006
# Epoch 97/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1002 - val_loss: 0.0977
# Epoch 98/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1001 - val_loss: 0.0990
# Epoch 99/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1003 - val_loss: 0.1018
# Epoch 100/100
# 235/235 [==============================] - 11s 49ms/step - loss: 0.1008 - val_loss: 0.1001

# %%
decoded_imgs = autoencoder.predict(test_images_saltpepper)

decoded_imgs_denoised = noise_removal_dae.predict(test_images_saltpepper)

n = 6
plt.figure(figsize=(20, 10))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(3, n, i)
    plt.imshow(test_images_saltpepper[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    if i==1:
        plt.ylabel("Original")
    else:
        ax.get_yaxis().set_visible(False)
        
    # Display reconstruction
    ax = plt.subplot(3, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    if i==1:
        plt.ylabel("Vanilla Autoencoder")
    else:
        ax.get_yaxis().set_visible(False)
     
    ax = plt.subplot(3, n, i + 2*n)
    plt.imshow(decoded_imgs_denoised[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    if i==1:
        plt.ylabel("Denoising Autoencoder")
    else:
        ax.get_yaxis().set_visible(False)
    
        
plt.show()
